# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import requests # Could use the builtin urllib but Requests are nicer.
    
import pandas as pd 
import csv
from datetime import datetime

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ant ='m009' 
month ='Feb'
sensors=(ant + '_' + month,ant + '_' + month)

# %%
 T_data=pd.read_csv(ant + '_' + month+ '.csv', header=None).T

# %%
T_list = list(T_data)
    
#map(list, zip(*T_list))
#list(map(list, zip(*T_data)))
#np.array(T_data).T.tolist()
#list(map(list, itertools.zip_longest(*T_data, fillvalue=None)))
print(T_list[0])
print(type(T_data[1][0]))
# Out:
# 0
# <class 'str'>

# %%
m033_x = []
m033_y = []
m033_az_drift=[]
m033_elev = []
m033_azim = []
m033_xFloat= []
date_time_str = []
date_time_sec= []
t_split = []
m033_May = []

for i in range(0, size(sensors) -1):
    with open(sensors[1] + '.csv', 'r') as csvfile:
         spamreader = csv.reader(csvfile, delimiter='\t')

         print(type(spamreader))
         rows_2 = list(spamreader) 
         m033_Jan = rows_2
         first_raw =rows_2[:1] 
         print(len(rows_2))
         #print(rows_2)
         #print(first_raw[0])
         #T_data= np.array(rows_2).T.tolist()

         #T_data2= np.array(T_data).T.tolist()
         #map(list, zip(*rows_2))
         list(map(list, zip(*rows_2)))
         print(rows_2[0][0])
         print(size(spamreader))
         print(type(rows_2[0][0]))
         for n in range(0,len(rows_2)-1):
             print(rows_2[n][3])
             t_split = (rows_2[n][1]).split(':')

             #m033_x.append(t_split[0] + '.' + t_split[1])
             m033_x.append(float(t_split[0] + '.' + t_split[1]))
             #m033_x.append(rows_2[n][1])
             m033_y.append(float(rows_2[n][5]))
             m033_az_drift.append(float(rows_2[n][4]))
             m033_elev.append(float(rows_2[n][3]))
             m033_azim.append(float(rows_2[n][2]))
             date_time_str.append( rows_2[n][0] + ' ' + rows_2[n][1])
             date_time_obj_start = datetime.strptime('2021-01-01 00:00:0.001', '%Y-%m-%d %H:%M:%S.%f')
             date_time_obj = datetime.strptime(date_time_str[n], '%Y-%m-%d %H:%M:%S.%f')
             time_diff = date_time_obj - date_time_obj_start
             date_time_sec.append(time_diff.total_seconds())

m033_xy = [m033_x,m033_y]             
         #print(rows_2[0:1][0:4])
#sorted_m033_x = m033_x.sort()
#sorted(m033_x)
#print( m033_xy.sort())
#print(m033_x)
#

#date_time_str = '2018-06-29 08:15:27.243860'
# time_now =datetime.now()
# date_time_obj = datetime.strptime(date_time_str[0], '%Y-%m-%d %H:%M:%S.%f')
# time_diff = time_now - date_time_obj

# print(time_diff.total_seconds())
# print('Date:', date_time_obj.date())
# print('Time:', date_time_obj.time())
# print('Date-time:', date_time_obj)

# min(range(len(m033_x)), key=lambda i: abs(m033_x[i]-15.5))
# min(enumerate(m033_x), key=lambda m033_x: abs(m033_x[1]-15.5))
# Out:
# <class '_csv.reader'>
# 53
# 2021-02-06
# 1
# <class 'str'>
# 24.82
# 20.78
# 24.28
# 50.75
# 23.36
# 52.13
# 25.35
# 24.90
# 56.04
# 54.72
# 25.76
# 57.33
# 61.20
# 27.60
# 47.66
# 46.54
# 31.10
# 25.71
# 24.33
# 28.28
# 23.21
# 29.27
# 51.23
# 50.73
# 21.49
# 51.62
# 26.18
# 49.25
# 55.43
# 45.25
# 51.79
# 56.96
# 53.99
# 54.55
# 34.11
# 46.55
# 43.65
# 50.21
# 54.38
# 55.00
# 44.38
# 54.95
# 47.56
# 55.02
# 52.88
# 54.27
# 50.24
# 45.02
# 53.91
# 52.93
# 51.65
# 53.67

# %%
# weather=('m033_enviro_air_temperature (1)','m033_enviro_air_temperature (1)'
#             )
weather=('m033_enviro_air_temperature (2)','m033_enviro_air_temperature (2)'
            )
# weather=('m033_enviro_air_temperature (3)','m033_enviro_air_temperature (3)'
#             )
# weather=('m033_enviro_air_temperature (4)','m033_enviro_air_temperature (4)'
#             )
# weather=('m033_enviro_air_temperature (5)','m033_enviro_air_temperature (5)'
#             )
#  weather=('m033_enviro_air_temperature_Jan','m033_enviro_air_temperature_Jan'
#             )
#,'m033_enviro_air_temperature (3)', 'm033_enviro_mean_wind_speed',
 #         'm033_enviro_mean_wind_speed (1)', 'm033_enviro_mean_wind_speed (2)', 'm033_enviro_mean_wind_speed (3)')
temp_x=[]
temp_y=[]
temp_y_mapped =[]
temp_x_obj=[]
temp_Mar=[]
temp_Apr=[]
temp_May=[]
wimd_Jan=[]
wimd_Feb=[]
wimd_Mar=[]
wimd_Apr=[]
wimd_May=[]




counter = 0 
deltaTime = 0
counter1 =0
pre_deltaTime = 0



#unique = []
matched_row = []
all_values =[]
date_time_str_2 = ''


for k in range(0, size(weather) -1):
    with open(weather[k] + '.csv', 'r') as csvfile:
        weather_data1 = csv.reader(csvfile, delimiter=',')
        weather_data = list(weather_data1)
        #print(weather_data[1069541][1])
        print(len(weather_data))
        
        list(map(list, zip(*weather_data)))

        for n in range(0,len(weather_data)-1):
            #print(weather_data[n][3])
            print(2)
            t_split = (weather_data[n][0]).split(' ')
          
            t_split2 = t_split[1].split(':')

            #m033_x.append(t_split[0] + '.' + t_split[1])
            #temp_x.append(float(t_split2[0] + '.' + t_split2[1]))
            #m033_x.append(rows_2[n][1])
            
            temp_y.append(float(weather_data[n][2]))

            date_time_str_2 = weather_data[n][0]
            strspli= date_time_str_2.split(' ')
            t_split = (strspli[1]).split(':')
            
            date_time_str_3 = strspli[0] + ' ' + strspli[1] 
            date_time_obj_2 = datetime.strptime(date_time_str_3, '%Y-%m-%d %H:%M:%S')

            date_time_obj  = '2021-01-01 00:00:0.001'  
            date_time_obj_1 = datetime.strptime(date_time_obj, '%Y-%m-%d %H:%M:%S.%f')


            time_diff = date_time_obj_2 - date_time_obj_1       


            time_dif_sec= time_diff.total_seconds()
            temp_x.append(float(t_split[0] + '.' + t_split[1]))
            temp_x_obj.append(time_dif_sec)
#print(temp_x_obj)
# temp_key=min(range(len(temp_x_obj)), key=lambda i: abs(temp_x_obj[i]-10825449.565))
# print(temp_key)
# print(date_time_sec)
for m in range(0, size(date_time_sec) ):
    temp_key=min(range(len(temp_x_obj)), key=lambda i: abs(temp_x_obj[i]- date_time_sec[m]))
    temp_y_mapped.append(temp_y[temp_key])
    print(temp_key)
    #print(date_time_sec[n])
   # print(temp_x_obj[0])
print(size(temp_x_obj))
print(size(date_time_sec))
print(size(temp_y_mapped))
# Out:
# 4028
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 718
# 1153
# 1214
# 1154
# 1386
# 1387
# 1388
# 1723
# 1725
# 1726
# 1722
# 1724
# 1721
# 1720
# 1794
# 1795
# 2319
# 2318
# 2390
# 2317
# 2320
# 2317
# 2555
# 2559
# 2732
# 2733
# 2727
# 2734
# 2843
# 2838
# 2988
# 3215
# 3700
# 3698
# 3674
# 3699
# 3697
# 3845
# 3843
# 3837
# 3887
# 3836
# 3843
# 3838
# 3990
# 3987
# 3989
# 3986
# 3988
# 4026
# 3992
# 3991
# 4027
# 52
# 52

# %%
# weather=('m033_enviro_mean_wind_speed','m033_enviro_mean_wind_speed'
#             )
weather=('m033_enviro_mean_wind_speed (1)','m033_enviro_mean_wind_speed (1)'
            )
# weather=('m033_enviro_mean_wind_speed (2)','m033_enviro_mean_wind_speed (2)'
#             )
# weather=('m033_enviro_mean_wind_speed (3)','m033_enviro_mean_wind_speed (3)'
#             )
# weather=('m033_enviro_mean_wind_speed (4)','m033_enviro_mean_wind_speed (4)'
#             )
# 

wind_x=[]
wind_y=[]
wind_y_mapped =[]
wind_x_obj=[]
wind_Mar=[]
wind_Apr=[]
wind_May=[]





counter = 0 
deltaTime = 0
counter1 =0
pre_deltaTime = 0



#unique = []
matched_row = []
all_values =[]
date_time_str_2 = ''


for k in range(0, size(weather) -1):
    with open(weather[k] + '.csv', 'r') as csvfile:
        weather_data1 = csv.reader(csvfile, delimiter=',')
        weather_data = list(weather_data1)
        #print(weather_data[1069541][1])
        print(len(weather_data))
        wind_Jan=weather_data
        list(map(list, zip(*weather_data)))

        for n in range(0,len(weather_data)-1):
            #print(weather_data[n][3])
            t_split = (weather_data[n][0]).split(' ')
            t_split2 = t_split[1].split(':')

            #m033_x.append(t_split[0] + '.' + t_split[1])
            #temp_x.append(float(t_split2[0] + '.' + t_split2[1]))
            #m033_x.append(rows_2[n][1])
            wind_y.append(float(weather_data[n][2]))

            date_time_str_2 = weather_data[n][0]
            strspli= date_time_str_2.split(' ')
            t_split = (strspli[1]).split(':')
            
            date_time_str_3 = strspli[0] + ' ' + strspli[1] 
            date_time_obj_2 = datetime.strptime(date_time_str_3, '%Y-%m-%d %H:%M:%S')

            date_time_obj  = '2021-01-01 00:00:0'  
            date_time_obj_1 = datetime.strptime(date_time_obj, '%Y-%m-%d %H:%M:%S')


            time_diff = date_time_obj_2 - date_time_obj_1       


            time_dif_sec= time_diff.total_seconds()
            wind_x.append(float(t_split[0] + '.' + t_split[1]))
            wind_x_obj.append(time_dif_sec)

for n in range(0, size(date_time_sec) ):
    wind_key=min(range(len(wind_x_obj)), key=lambda i: abs(wind_x_obj[i]-date_time_sec[n]))
    wind_y_mapped.append(wind_y[wind_key])
    #print(wind_key)
    print(wind_y[wind_key])
print(size(date_time_sec))                  
print(size(wind_y_mapped))
# Out:
# 4027
# 4.64095240635083
# 5.089745034171506
# 2.5799969719238334
# 4.9537690747791725
# 2.093746045944998
# 1.7143525040379997
# 1.642383249618666
# 3.015452587188332
# 3.130215549326165
# 2.975618164493832
# 3.1373543511639994
# 3.022704302689002
# 3.3190194617426694
# 3.6122954112833328
# 4.434937120874503
# 5.010494183451672
# 2.4390112320978323
# 2.122149765211333
# 5.909368491542498
# 1.9017329591981669
# 2.5068766522544994
# 1.9017329591981669
# 2.927421756031329
# 3.158033527350668
# 3.2511300892836643
# 3.4349542300121696
# 2.604380785139664
# 3.8250106750276656
# 5.055719207905665
# 4.519254190369502
# 2.275056997228331
# 3.8977512406088324
# 3.3414306532776603
# 3.001790701376499
# 2.2795952645386657
# 2.837472224565333
# 3.3114367285419983
# 0.9210192818213333
# 1.0258842084335
# 1.7277400763116675
# 6.681475527050657
# 1.3061447987706665
# 1.0258842084335
# 2.1959082001671675
# 3.6511803711346675
# 5.5581008675356625
# 4.585571917043168
# 5.251792224985337
# 5.234399529191832
# 3.6625667622248375
# 3.1834411560521647
# 3.2066019656361657
# 52
# 52

# %%
#sort m033_y list by m033_x
zipped_lists = zip(m033_x, m033_y)
    
    
sorted_zipped_lists = sorted(zipped_lists)


sorted_el_drift = [element for _, element in sorted_zipped_lists]

print(sorted_el_drift)

#m033_x.sort()
# Out:
# [0.2, 0.37, 0.1, 0.52, 0.15, 0.14, 0.51, 0.0, -0.03, 0.19, 0.04, 0.13, 1.04, 0.15, -0.23, -0.32, -0.36, -0.17, 0.02, -0.05, 0.26, -0.21, -0.0, -0.0, -0.07, 0.0, 0.02, 0.3, 0.61, 0.05, 1.85, -0.06, 0.14, -0.21, 0.01, 0.0, 0.17, 0.57, -0.04, 0.01, -0.14, 0.11, -0.03, 0.15, 0.31, 0.5, 0.42, 0.23, 0.49, 0.5, 0.16, 0.91]

# %%
zipped_lists = zip(m033_x, m033_az_drift)
    
    
sorted_zipped_lists = sorted(zipped_lists)


sorted_az_drift = [element for _, element in sorted_zipped_lists]

print(sorted_az_drift)

#m033_x.sort()
# Out:
# [0.1, 0.05, -0.14, -1.03, -0.51, -0.43, -0.39, -0.13, -0.14, -0.21, 0.14, -0.47, -0.59, 0.07, -0.01, -0.39, -0.44, -0.14, -0.38, -0.63, -1.04, -0.23, -0.83, -0.68, -0.49, -0.35, -0.44, -0.75, -0.79, -0.4, 0.82, 0.24, -0.3, -0.55, -0.55, -0.84, -0.71, -0.56, 0.31, -0.31, -0.3, -0.29, -0.2, -0.33, -0.53, -0.98, -0.1, -0.4, -0.16, 0.14, -0.32, 0.15]

# %%
zipped_lists = zip(m033_x, m033_elev)
    
    
sorted_zipped_lists = sorted(zipped_lists)


sorted_elev = [element for _, element in sorted_zipped_lists]

print(sorted_elev)

#m033_x.sort()
# Out:
# [56.04, 51.62, 54.72, 24.82, 49.25, 44.38, 20.78, 50.75, 28.28, 29.27, 25.71, 31.1, 23.21, 56.96, 24.28, 47.66, 46.54, 34.11, 24.33, 23.36, 52.13, 25.35, 54.95, 55.0, 55.02, 43.65, 45.02, 54.55, 54.38, 54.27, 52.93, 46.55, 47.56, 53.91, 53.99, 50.24, 50.21, 52.88, 45.25, 53.67, 51.65, 51.23, 55.43, 51.79, 50.73, 26.18, 27.6, 61.2, 25.76, 24.9, 21.49, 57.33]

# %%
zipped_lists = zip(m033_x, m033_azim)
    
    
sorted_zipped_lists = sorted(zipped_lists)


sorted_azim = [element for _, element in sorted_zipped_lists]

print(sorted_azim)

#m033_x.sort()
# Out:
# [224.06, 226.36, 224.89, 206.7, 227.12, 227.95, 204.68, 226.67, 225.89, 149.55, 225.04, 149.21, 224.07, 183.35, 153.53, 206.41, 207.32, 211.06, 208.89, 208.47, 164.33, 135.09, 177.35, 178.47, 179.79, 132.0, 132.11, 186.65, 187.73, 188.36, 134.2, 132.31, 132.49, 190.1, 189.71, 133.17, 133.16, 193.69, 132.14, 134.55, 196.74, 133.5, 135.55, 196.45, 198.54, 207.21, 207.66, 219.15, 207.06, 206.73, 205.09, 223.11]

# %%
zipped_lists = zip(m033_x, temp_y_mapped)
    
    
sorted_zipped_lists = sorted(zipped_lists)


sorted_temp = [element for _, element in sorted_zipped_lists]

print(temp_y_mapped)

# m033_x.sort()
# Out:
# [27.337375000000005, 24.67100000000001, 35.38604166666666, 24.595416666666672, 38.763375000000025, 38.671249999999986, 38.25791666666664, 25.000583333333317, 24.85616666666664, 24.73525, 25.11895833333331, 24.912708333333324, 25.305083333333336, 25.56745833333332, 33.82066666666667, 33.24620833333332, 16.453875000000007, 16.711166666666667, 33.49425000000001, 17.228708333333326, 16.457625, 17.228708333333326, 24.270916666666665, 23.97591666666668, 18.108916666666683, 17.947416666666665, 18.263166666666674, 17.85975, 23.543416666666655, 24.875166666666658, 24.180125000000007, 28.48916666666666, 29.547000000000008, 30.778958333333314, 30.879541666666675, 29.877124999999996, 30.778499999999983, 30.53691666666668, 31.336249999999993, 33.02654166666667, 24.371791666666677, 33.18545833333332, 31.336249999999993, 32.41470833333334, 29.348833333333335, 30.140333333333338, 29.63208333333333, 30.857874999999993, 29.855166666666683, 22.10066666666666, 28.87083333333332, 29.080249999999992]

# %%
zipped_lists = zip(m033_x, wind_y_mapped)
    
    
sorted_zipped_lists = sorted(zipped_lists)


sorted_wind = [element for _, element in sorted_zipped_lists]

print(sorted_azim)

m033_x.sort()
# Out:
# [224.06, 226.36, 224.89, 206.7, 227.12, 227.95, 204.68, 226.67, 225.89, 149.55, 225.04, 149.21, 224.07, 183.35, 153.53, 206.41, 207.32, 211.06, 208.89, 208.47, 164.33, 135.09, 177.35, 178.47, 179.79, 132.0, 132.11, 186.65, 187.73, 188.36, 134.2, 132.31, 132.49, 190.1, 189.71, 133.17, 133.16, 193.69, 132.14, 134.55, 196.74, 133.5, 135.55, 196.45, 198.54, 207.21, 207.66, 219.15, 207.06, 206.73, 205.09, 223.11]

# %%
# fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
# #ax.plot( m033_xy[0], sorted_list1)
# ax[0][0].errorbar(m033_xy[0],sorted_el_drift, fmt='-o')
# ax[0][0].set(xlabel='Time of day in hours (UTC)', ylabel='Pointing shift in elevation (arcmin)',
#        title=ant + ' pointing elevation shifts in ' + month+' 2021')
# #ax.grid()
# ax[0][1].errorbar(m033_xy[0],m033_elev,yerr=sorted_el_drift, fmt='o')
# ax[0][1].set(xlabel='Time of day in hours (UTC)', ylabel='Elevation angle with pointing error (degrees)',
#        title=ant + ' pointing check elevation angles in ' + month+' 2021   ')
# #ax.grid()
# ax[1][0].errorbar(temp_x,temp_y, fmt='-o')
# ax[1][0].set(xlabel='Time of day in hours (UTC)', ylabel='Air temperature ($^\circ$C)',
#        title='Average air temperature pattern on 01 ' + month+' 2021   ')
# #ax.grid()
# ax[1][1].errorbar(wind_x,wind_y, fmt='-o')
# ax[1][1].set(xlabel='Time of day in hours (UTC)', ylabel='Average wind speed (m/s)',
#        title='Average wind speed pattern on 01 ' + month+' 2021   ')
# #ax.grid()
# fig.savefig(ant+"_elev_" + month+".png")
# plt.show()

# %%
# fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
# #ax.plot( m033_xy[0], sorted_list1)
# ax[0][0].errorbar(m033_xy[0],sorted_az_drift, fmt='-o')
# ax[0][0].set(xlabel='Time of day in hours (UTC)', ylabel='Pointing shift in azimuth (arcmin)',
#        title=ant+' pointing azimuth shifts  in ' + month+' 2021')
# #ax.grid()
# ax[0][1].errorbar(m033_xy[0],m033_azim,yerr=sorted_az_drift, fmt='o')
# ax[0][1].set(xlabel='Time of day in hours (UTC)', ylabel='Azimuth angle with pointing error (degrees)',
#        title=ant+' pointing azimuth shift in ' + month+' 2021')
# #ax.grid()
# ax[1][0].errorbar(temp_x,temp_y, fmt='-o')
# ax[1][0].set(xlabel='Time of day in hours (UTC)', ylabel='Air temperature ($^\circ$C)',
#        title='Average air temperature pattern on 01 ' + month+' 2021')
# #ax.grid()
# ax[1][1].errorbar(wind_x,wind_y, fmt='-o')
# ax[1][1].set(xlabel='Time of day in hours (UTC)', ylabel='Average wind speed (m/s)',
#        title='Average wind speed pattern on 01 ' + month+' 2021 ')
# #ax.grid()
# fig.savefig(ant+"_azim_" + month+".png")
# plt.show()

# %%
# fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
# #ax.plot( m033_xy[0], sorted_list1)
# ax[0][0].errorbar(m033_xy[0],sorted_el_drift, fmt='-o')
# ax[0][0].set(xlabel='Time of day in hours (UTC)', ylabel='Pointing shift in elevation (arcmin)',
#        title=ant + ' pointing check elevation angles in ' + month+' 2021   ')
# #ax.grid()
# ax[0][1].errorbar(m033_xy[0],m033_elev,yerr=sorted_el_drift, fmt='o')
# ax[0][1].set(xlabel='Time of day in hours (UTC)', ylabel='Elevation angle with pointing error (degrees)',
#        title='m033 pointing check elevation angles in May 2021   ')
# #ax.grid()
# ax[1][0].errorbar(temp_x,temp_y, fmt='-o')
# ax[1][0].set(xlabel='Time of day in hours (UTC)', ylabel='Air temperature ($^\circ$C)',
#        title='Average air temperature pattern on 01 May 2021   ')
# #ax.grid()
# ax[1][1].errorbar(wind_x,wind_y, fmt='-o')
# ax[1][1].set(xlabel='Time of day in hours (UTC)', ylabel='Average wind speed (m/s)',
#        title='Average wind speed pattern on 01 May 2021   ')
# #ax.grid()
# fig.savefig("m033_elev_May.png")
# plt.show()

# %%
# fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
# #ax.plot( m033_xy[0], sorted_list1)
# ax[0][0].errorbar(m033_xy[0],sorted_az_drift, fmt='-o')
# ax[0][0].set(xlabel='Time of day in hours (UTC)', ylabel='Pointing shift in azimuth (arcmin)',
#        title='m033 pointing check elevation offsets in May 2021')
# #ax.grid()
# ax[0][1].errorbar(m033_xy[0],m033_azim,yerr=sorted_el_drift, fmt='o')
# ax[0][1].set(xlabel='Time of day in hours (UTC)', ylabel='Azimuth angle and offset error (degrees)',
#        title='m033 pointing azimuth shift in Jan 2021')
# #ax.grid()
# ax[1][0].errorbar(temp_x,temp_y, fmt='-o')
# ax[1][0].set(xlabel='Time of day in hours (UTC)', ylabel='Air temperature ($^\circ$C)',
#        title='Average air temperature pattern on 01 May 2021   ')
# #ax.grid()
# ax[1][1].errorbar(wind_x,wind_y, fmt='-o')
# ax[1][1].set(xlabel='Time of day in hours (UTC)', ylabel='Average wind speed (m/s)',
#        title='Average wind speed pattern on 01 May 2021 ')
# #ax.grid()
# fig.savefig("m033_azim_May.png")
# plt.show()

# %%
print(size(temp_y_mapped))
print(size(m033_x))
# Out:
# 52
# 52

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
#ax.plot( m033_xy[0], sorted_list1)
ax[0][0].errorbar(m033_xy[0],sorted_el_drift, fmt='-o')
ax[0][0].set(xlabel='Time of day in hours (UTC)', ylabel='Pointing shift in elevation (arcmin)',
       title=ant + ' pointing elevation shifts in ' + month+' 2021')
#ax.grid()
ax[0][1].errorbar(m033_xy[0],sorted_elev,yerr=sorted_el_drift, fmt='o')
ax[0][1].set(xlabel='Time of day in hours (UTC)', ylabel='Elevation angle with pointing error (degrees)',
       title=ant + ' pointing check elevation angles in ' + month+' 2021   ')
#ax.grid()
ax[1][0].errorbar(m033_x,sorted_temp, fmt='-o')
ax[1][0].set(xlabel='Time of day in hours (UTC)', ylabel='Air temperature ($^\circ$C)',
       title='Average air temperature in ' + month+' 2021   ')
#ax.grid()
ax[1][1].errorbar(m033_x,sorted_wind, fmt='-o')
ax[1][1].set(xlabel='Time of day in hours (UTC)', ylabel='Average wind speed (m/s)',
       title='Average wind speed in ' + month+' 2021   ')
#ax.grid()
fig.savefig(ant+"_elev_" + month+"_mapped.png")
plt.show()

# %%
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(15,15))
#ax.plot( m033_xy[0], sorted_list1)
ax[0][0].errorbar(m033_xy[0],sorted_az_drift, fmt='-o')
ax[0][0].set(xlabel='Time of day in hours (UTC)', ylabel='Pointing shift in azimuth (arcmin)',
       title=ant + ' pointing azim shifts in ' + month+' 2021')
#ax.grid()
ax[0][1].errorbar(m033_xy[0],sorted_azim,yerr=sorted_az_drift, fmt='o')
ax[0][1].set(xlabel='Time of day in hours (UTC)', ylabel='Azimuth angle and offset error (degrees)',
       title=ant + ' pointing Azim offsets in ' + month+' 2021')
#ax.grid()
ax[1][0].errorbar(m033_x,sorted_temp, fmt='-o')
ax[1][0].set(xlabel='Time of day in hours (UTC)', ylabel='Air temperature ($^\circ$C)',
       title='Average air temperature in' + month+' 2021')
#ax.grid()
ax[1][1].errorbar(m033_x,sorted_wind, fmt='-o')
ax[1][1].set(xlabel='Time of day in hours (UTC)', ylabel='Average wind speed (m/s)',
       title='Average wind speed in ' + month+' 2021')
#ax.grid()
fig.savefig(ant+"_azim_" + month+"_mapped.png")
plt.show()

# %%
print(max(sorted_el_drift))
print(max(sorted_az_drift))

max_index = sorted_el_drift.index(max(sorted_el_drift))
print(max_index)
# Out:
# 1.85
# 0.82
# 30

# %%
np.corrcoef(sorted_temp,sorted_az_drift)
# Out:
# array([[ 1.        , -0.29040526],
#        [-0.29040526,  1.        ]])

# %%
np.corrcoef(sorted_wind,sorted_az_drift)
# Out:
# array([[1.        , 0.10331426],
#        [0.10331426, 1.        ]])

# %%
np.corrcoef(sorted_temp,sorted_el_drift)
# Out:
# array([[ 1.        , -0.39371716],
#        [-0.39371716,  1.        ]])

# %%
np.corrcoef(sorted_wind,sorted_el_drift)
# Out:
# array([[ 1.        , -0.06434288],
#        [-0.06434288,  1.        ]])

# %%
sorted_el_drift_abs= list(map(abs, sorted_el_drift))
sorted_az_drift_abs= list(map(abs, sorted_az_drift))
print(sorted_el_drift_abs)
# Out:
# [0.2, 0.37, 0.1, 0.52, 0.15, 0.14, 0.51, 0.0, 0.03, 0.19, 0.04, 0.13, 1.04, 0.15, 0.23, 0.32, 0.36, 0.17, 0.02, 0.05, 0.26, 0.21, 0.0, 0.0, 0.07, 0.0, 0.02, 0.3, 0.61, 0.05, 1.85, 0.06, 0.14, 0.21, 0.01, 0.0, 0.17, 0.57, 0.04, 0.01, 0.14, 0.11, 0.03, 0.15, 0.31, 0.5, 0.42, 0.23, 0.49, 0.5, 0.16, 0.91]

# %%
np.corrcoef(sorted_temp,sorted_el_drift_abs)
# Out:
# array([[ 1.       , -0.2314497],
#        [-0.2314497,  1.       ]])

# %%
np.corrcoef(sorted_wind,sorted_el_drift_abs)
# Out:
# array([[ 1.        , -0.01613936],
#        [-0.01613936,  1.        ]])

# %%
np.corrcoef(sorted_temp,sorted_az_drift_abs)
# Out:
# array([[1.        , 0.22792861],
#        [0.22792861, 1.        ]])

# %%
np.corrcoef(sorted_wind,sorted_az_drift_abs)
# Out:
# array([[ 1.       , -0.0911859],
#        [-0.0911859,  1.       ]])

# %%
print(max(sorted_el_drift_abs))
print(max(sorted_az_drift_abs))

max_el_index = sorted_el_drift_abs.index(max(sorted_el_drift_abs))
max_az_index = sorted_az_drift_abs.index(max(sorted_az_drift_abs))


print(max_el_index)
print(max_az_index)
print(sorted_temp[max_el_index])
print(sorted_wind[max_el_index])
print(sorted_temp[max_az_index])
print(sorted_wind[max_az_index])

max_el_index_1 = sorted_el_drift_abs.index(sorted(sorted_el_drift_abs)[-2])
max_az_index_1 = sorted_az_drift_abs.index(sorted(sorted_az_drift_abs)[-2])

print(sorted_temp[max_el_index_1])
print(sorted_wind[max_el_index_1])
print(sorted_temp[max_az_index_1])
print(sorted_wind[max_az_index_1])
# Out:
# 0.98
# 2.94
# 37
# 57
# 33.88025
# 6.72261470598
# 24.393500000000014
# 4.1628988455
# 12.656375000000002
# 0.8166506177
# 26.941833333333342
# 8.679660503860001

# %%
print(min(sorted_el_drift_abs))
print(min(sorted_az_drift_abs))

min_el_index = sorted_el_drift_abs.index(min(sorted_el_drift_abs))
min_az_index = sorted_az_drift_abs.index(min(sorted_az_drift_abs))

min_el_index_1 = sorted_el_drift_abs.index(min(sorted_el_drift_abs))
min_az_index_1 = sorted_az_drift_abs.index(min(sorted_az_drift_abs))


print(min_el_index)
print(min_az_index)
print(sorted_temp[min_el_index])
print(sorted_wind[min_el_index])
print(sorted_temp[min_az_index])
print(sorted_wind[min_az_index])
# Out:
# 0.03
# 0.0
# 48
# 45
# 25.504166666666677
# 1.4215826910300002
# 28.148416666666694
# 6.554619893150002

# %%
average_max= (sorted(sorted_az_drift_abs)[-1] + sorted(sorted_az_drift_abs)[-4]+ sorted(sorted_az_drift_abs)[-3]+sorted(sorted_az_drift_abs)[-2])/4
print(average_max)
# Out:
# 1.6725

# %%
average_max= sorted(sorted_az_drift_abs)[-1] + sorted(sorted_az_drift_abs)[-4]+ sorted(sorted_az_drift_abs)[-3]+sorted(sorted_az_drift_abs)[-2]
print(average_max)
